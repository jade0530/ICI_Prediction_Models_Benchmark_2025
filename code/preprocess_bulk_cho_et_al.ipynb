# %% [markdown]
# ## Preprocess bulk-RNA seq data (Cho et al., GSE126044)
# This notebook processes raw count data from the Cho et al. study

# %%
import anndata as ad
import scanpy as sc
import pandas as pd
from rnanorm.datasets import load_toy_data
from rnanorm import FPKM, TPM, CPM, TMM

# %%
# Load gene mapping data and compass example data
gene_list_with_synoy = pd.read_table("/Users/z5155527/Desktop/Benchmark-2025-Sep/phase_1_datasets/bulk_RNA-seq/braun_bulk_cleaned/Homo_sapiens.gene_info", sep = '\t')
gene_list_with_synoy = gene_list_with_synoy.loc[:, ["Symbol", "Synonyms"]]
gene_list_with_synoy['Synonyms_separated'] = gene_list_with_synoy['Synonyms'].str.split('|')
gene_list_with_synoy = gene_list_with_synoy.explode('Synonyms_separated')
gene_list_with_synoy = gene_list_with_synoy.drop(columns="Synonyms")

compass_example_data = pd.read_csv("/Users/z5155527/Desktop/Benchmark-2025-Sep/phase_1_datasets/bulk_RNA-seq/compass_gide_tpm.tsv", sep='\t')
compass_example_data_genelist = compass_example_data.columns.tolist()

# %%
# code from COMPASS
# load the gene length
gtf_path = '/Users/z5155527/Desktop/Benchmark-2025-Sep/external_validation_datasets/code/gencode.v19.chr_patch_hapl_scaff.annotation.gtf'
import gzip

# Parse the GTF file to create a mapping from gene_id to gene symbol
gene_id_to_symbol = {}

with open(gtf_path, 'r') as gtf_file:
    for line in gtf_file:
        if line.startswith('#'):
            continue
        fields = line.strip().split('\t')
        if fields[2] != 'gene':
            continue
        # Parse attributes field
        attributes_field = fields[8]
        attributes = {}
        for attr in attributes_field.strip().split(';'):
            if attr.strip() == '':
                continue
            key, value = attr.strip().split(' ', 1)
            attributes[key] = value.strip().replace('"', '')
        gene_id = attributes.get('gene_id', None)
        gene_symbol = attributes.get('gene_name', None)
        if gene_id and gene_symbol:
            gene_id_to_symbol[gene_id] = gene_symbol

# Convert to DataFrame for easier use
gene_id_symbol_df = pd.DataFrame(list(gene_id_to_symbol.items()), columns=['gene_id_gencode19', 'gene_symbol'])
gene_id_symbol_df["gene_id"] = gene_id_symbol_df["gene_id_gencode19"].str.split(".", expand=True)[0]

gene_id_symbol_df.head()
# Out:
#    gene_id_gencode19 gene_symbol          gene_id
# 0  ENSG00000223972.4     DDX11L1  ENSG00000223972
# 1  ENSG00000227232.4      WASH7P  ENSG00000227232
# 2  ENSG00000243485.2  MIR1302-11  ENSG00000243485
# 3  ENSG00000237613.2     FAM138A  ENSG00000237613
# 4  ENSG00000268020.2      OR4G4P  ENSG00000268020

# %%
# -----------------------------------------------------
# Parse GFF3 (GENCODE v36, GRCh38) and extract mapping from gene_id to gene symbol
# For use in mapping RNA-seq columns (gene ids or gene symbols) to GENCODE annotation
# -----------------------------------------------------

# Path to GFF3 annotation file (GENCODE v36, GRCh38)
gtf_path = '/Users/z5155527/Desktop/Benchmark-2025-Sep/external_validation_datasets/code/Homo_sapiens.GRCh38.115.gff3'

import gzip

# Dictionary to store mapping: gene_id (from 'ID') -> gene_symbol (from 'Name')
gene_id_to_symbol = {}

with open(gtf_path, 'r') as gff3_file:
    for line in gff3_file:
        # Skip comment/header lines
        if line.startswith('#'):
            continue
        fields = line.strip().split('\t')
        # Ignore lines with fewer than 9 fields or non-gene features
        if len(fields) < 9:
            continue
        if fields[2] != 'gene':
            continue
        # Parse the attributes column into a dict
        attributes_field = fields[8]
        attributes = {}
        for attr in attributes_field.strip().split(';'):
            attr = attr.strip()
            # Skip blank or malformed attributes
            if attr == '':
                continue
            if '=' not in attr:
                continue
            key, value = attr.split('=', 1)
            attributes[key] = value
        # Get GFF3-style gene_id and symbol
        gene_id = attributes.get('ID', None)        # e.g. "gene:ENSG00000186092"
        gene_symbol = attributes.get('Name', None)  # e.g. "OR4F5"
        if gene_id and gene_symbol:
            gene_id_to_symbol[gene_id] = gene_symbol

# Convert the mapping dict into a DataFrame for downstream use
gene_id_symbol_df = pd.DataFrame(list(gene_id_to_symbol.items()), columns=['gene_id_gencode36', 'gene_symbol'])
# Remove any version suffix: take only the part before the first dot from 'gene_id_gencode36'
gene_id_symbol_df["gene_id"] = gene_id_symbol_df["gene_id_gencode36"].str.split(".", expand=True)[0]

# Preview resulting id -> symbol table
gene_id_symbol_df.head()
# Out:
#       gene_id_gencode36 gene_symbol               gene_id
# 0  gene:ENSG00000186092       OR4F5  gene:ENSG00000186092
# 1  gene:ENSG00000284733      OR4F29  gene:ENSG00000284733
# 2  gene:ENSG00000284662      OR4F16  gene:ENSG00000284662
# 3  gene:ENSG00000187634      SAMD11  gene:ENSG00000187634
# 4  gene:ENSG00000188976       NOC2L  gene:ENSG00000188976

# %%
gene_id_symbol_df.to_csv('/Users/z5155527/Desktop/Benchmark-2025-Sep/external_validation_datasets/code/gene_id_symbol_hg38.csv')

# %%
# try a 18 sample raw count data on compass
cho_et_al = pd.read_csv("/Users/z5155527/Desktop/Benchmark-2025-Sep/phase_1_datasets/bulk_RNA-seq/raw_count_final/cho_et_al_counts.txt", sep = '\t')
cho_et_al.index = cho_et_al["Unnamed: 0"].tolist()
cho_et_al = cho_et_al.drop(columns="Unnamed: 0").T
cho_et_al
# Out:
#         OR4F5  OR4F29  OR4F16  LINC00115  SAMD11  NOC2L  KLHL17  PLEKHN1  \
# Dis_01      2       0       0         49     176   6343     339       86
# Dis_02      0       0       0         26      14   3154      59       18
# Dis_11      0       0       0         47       5   3656      81        5
# Dis_12      0       0       0         29       5   3656     362      625
# Dis_15      0       0       0         41      25   2665     279      139
# Dis_04      0       0       0         27      22    983     133       25
# Dis_16      0       0       0         59      28   4853     228      235
# Dis_17      0       0       0         43      69   2553     220       96
# Dis_03      6       0       0         39      62   2609     139      143
# Dis_07      0       0       0         29      40   2100      80       27
# Dis_10      1       0       0         24      48   1105     142       72
# Dis_18      0       0       0         24       9   2003     198      265
# Dis_09      0       0       1         39      20   2332     240      215
# Dis_05      0       0       0         69     115   1371     309      161
# Dis_06      1       0       0         24       7   2867     191      109
# Dis_08      0       0       0         37      15   1249     134      131
#
#         HES4  ISG15  ...  PRY  BPY2  DAZ1  DAZ2  CDY1B  BPY2B  DAZ3  DAZ4  \
# Dis_01    59     52  ...    0     0     8   388      0      0    14     8
# Dis_02    50     43  ...    0     0     0     0      0      0     0     0
# Dis_11    16     29  ...    0     0    11    31      0      0   161    21
# Dis_12   301   1232  ...    0     0     0     0      0      0     0     0
# Dis_15    79    140  ...    0     0     0     0      0      0     0     0
# Dis_04    19     76  ...    0     0     0     0      0      0     0     0
# Dis_16   387    248  ...    0     0     0     0      0      0     0     0
# Dis_17   325    104  ...    0     0     0     0      0      0     0     0
# Dis_03   192    380  ...    0     0     0     0      0      0     0     1
# Dis_07    47     33  ...    0     0     0     0      0      0     0     0
# Dis_10   114    269  ...    0     0     0     5      0      0     1     2
# Dis_18    77    240  ...    0     0     0     0      0      0     0     0
# Dis_09    86    243  ...    0     0     0     0      0      0    15    14
# Dis_05   150     57  ...    0     0     0     0      0      0     0     0
# Dis_06    54    132  ...    0     0     0     0      0      0     0     0
# Dis_08   137    245  ...    0     0     0     0      0      0     0     0
#
#         BPY2C  CDY1
# Dis_01      0     0
# Dis_02      0     0
# Dis_11      0     0
# Dis_12      0     0
# Dis_15      0     0
# Dis_04      0     0
# Dis_16      0     0
# Dis_17      0     0
# Dis_03      0     0
# Dis_07      0     0
# Dis_10      0     0
# Dis_18      0     0
# Dis_09      0     0
# Dis_05      0     0
# Dis_06      0     0
# Dis_08      0     0
#
# [16 rows x 18747 columns]

# %%
cho_et_al.shape
# Out:
# (16, 18747)

# %%
# map genes ids to gene symbols
cho_et_al_gene_list = cho_et_al.columns.tolist()
print("Length of cho_et_al_gene_list:", len(cho_et_al_gene_list))
print("Length of gene_id_symbol_df:", len(gene_id_symbol_df))

# Find overlap between cho_et_al_gene_list and gene_id_symbol_df["gene_id"]
gene_id_set = set(gene_id_symbol_df["gene_symbol"])
cho_et_al_gene_set = set(cho_et_al_gene_list)

# Genes in cho_et_al that are also in the GTF gene_id list
overlap_genes = cho_et_al_gene_set & gene_id_set
num_overlap = len(overlap_genes)

# Genes in cho_et_al that could not be mapped (not found in gene_id_symbol_df)
unmapped_genes = cho_et_al_gene_set - gene_id_set
num_unmapped = len(unmapped_genes)

print(f"Number of genes overlapped between cho_et_al and GTF gene_id list: {num_overlap}")
print(f"Number of genes in cho_et_al that could not be mapped: {num_unmapped}")
unmapped_genes
# Out:
# Length of cho_et_al_gene_list: 18747
# Length of gene_id_symbol_df: 63568
# Number of genes overlapped between cho_et_al and GTF gene_id list: 18720
# Number of genes in cho_et_al that could not be mapped: 25
# {'1-Dec',
#  '1-Mar',
#  '1-Sep',
#  '10-Mar',
#  '10-Sep',
#  '11-Mar',
#  '11-Sep',
#  '12-Sep',
#  '14-Sep',
#  '2-Mar',
#  '2-Sep',
#  '3-Mar',
#  '3-Sep',
#  '4-Mar',
#  '4-Sep',
#  '5-Mar',
#  '5-Sep',
#  '6-Mar',
#  '6-Sep',
#  '7-Mar',
#  '7-Sep',
#  '8-Mar',
#  '8-Sep',
#  '9-Mar',
#  '9-Sep'}

# %%
unmapped_genes_df = pd.DataFrame(unmapped_genes, columns=["unmapped_genes"])
unmapped_genes_df["split_mapped"] = unmapped_genes_df["unmapped_genes"].str.split("-", expand=True)[0]
unmapped_genes_df["split_name"] = unmapped_genes_df["unmapped_genes"].str.split("-", expand=True)[1]
unmapped_genes_df.loc[unmapped_genes_df["split_name"]=="Sep", "new_name"] = "SEPT"
unmapped_genes_df.loc[unmapped_genes_df["split_name"]=="Dec", "new_name"] = "DEC"
unmapped_genes_df.loc[unmapped_genes_df["split_name"]=="Mar", "new_name"] = "MARCH"
unmapped_genes_df["new_gene_name"] = unmapped_genes_df["new_name"] + unmapped_genes_df["split_mapped"]
map_gene_dict = dict(zip(unmapped_genes_df["unmapped_genes"], unmapped_genes_df["new_gene_name"]))
map_gene_dict
# Out:
# {'6-Mar': 'MARCH6',
#  '5-Mar': 'MARCH5',
#  '11-Sep': 'SEPT11',
#  '8-Sep': 'SEPT8',
#  '7-Sep': 'SEPT7',
#  '1-Dec': 'DEC1',
#  '11-Mar': 'MARCH11',
#  '1-Sep': 'SEPT1',
#  '5-Sep': 'SEPT5',
#  '4-Mar': 'MARCH4',
#  '8-Mar': 'MARCH8',
#  '12-Sep': 'SEPT12',
#  '14-Sep': 'SEPT14',
#  '9-Sep': 'SEPT9',
#  '6-Sep': 'SEPT6',
#  '9-Mar': 'MARCH9',
#  '1-Mar': 'MARCH1',
#  '10-Sep': 'SEPT10',
#  '3-Mar': 'MARCH3',
#  '10-Mar': 'MARCH10',
#  '2-Mar': 'MARCH2',
#  '4-Sep': 'SEPT4',
#  '3-Sep': 'SEPT3',
#  '2-Sep': 'SEPT2',
#  '7-Mar': 'MARCH7'}

# %%
# rename cho_et_al columns by dictionary
cho_et_al = cho_et_al.rename(columns=map_gene_dict)
cho_et_al
# Out:
#         OR4F5  OR4F29  OR4F16  LINC00115  SAMD11  NOC2L  KLHL17  PLEKHN1  \
# Dis_01      2       0       0         49     176   6343     339       86
# Dis_02      0       0       0         26      14   3154      59       18
# Dis_11      0       0       0         47       5   3656      81        5
# Dis_12      0       0       0         29       5   3656     362      625
# Dis_15      0       0       0         41      25   2665     279      139
# Dis_04      0       0       0         27      22    983     133       25
# Dis_16      0       0       0         59      28   4853     228      235
# Dis_17      0       0       0         43      69   2553     220       96
# Dis_03      6       0       0         39      62   2609     139      143
# Dis_07      0       0       0         29      40   2100      80       27
# Dis_10      1       0       0         24      48   1105     142       72
# Dis_18      0       0       0         24       9   2003     198      265
# Dis_09      0       0       1         39      20   2332     240      215
# Dis_05      0       0       0         69     115   1371     309      161
# Dis_06      1       0       0         24       7   2867     191      109
# Dis_08      0       0       0         37      15   1249     134      131
#
#         HES4  ISG15  ...  PRY  BPY2  DAZ1  DAZ2  CDY1B  BPY2B  DAZ3  DAZ4  \
# Dis_01    59     52  ...    0     0     8   388      0      0    14     8
# Dis_02    50     43  ...    0     0     0     0      0      0     0     0
# Dis_11    16     29  ...    0     0    11    31      0      0   161    21
# Dis_12   301   1232  ...    0     0     0     0      0      0     0     0
# Dis_15    79    140  ...    0     0     0     0      0      0     0     0
# Dis_04    19     76  ...    0     0     0     0      0      0     0     0
# Dis_16   387    248  ...    0     0     0     0      0      0     0     0
# Dis_17   325    104  ...    0     0     0     0      0      0     0     0
# Dis_03   192    380  ...    0     0     0     0      0      0     0     1
# Dis_07    47     33  ...    0     0     0     0      0      0     0     0
# Dis_10   114    269  ...    0     0     0     5      0      0     1     2
# Dis_18    77    240  ...    0     0     0     0      0      0     0     0
# Dis_09    86    243  ...    0     0     0     0      0      0    15    14
# Dis_05   150     57  ...    0     0     0     0      0      0     0     0
# Dis_06    54    132  ...    0     0     0     0      0      0     0     0
# Dis_08   137    245  ...    0     0     0     0      0      0     0     0
#
#         BPY2C  CDY1
# Dis_01      0     0
# Dis_02      0     0
# Dis_11      0     0
# Dis_12      0     0
# Dis_15      0     0
# Dis_04      0     0
# Dis_16      0     0
# Dis_17      0     0
# Dis_03      0     0
# Dis_07      0     0
# Dis_10      0     0
# Dis_18      0     0
# Dis_09      0     0
# Dis_05      0     0
# Dis_06      0     0
# Dis_08      0     0
#
# [16 rows x 18747 columns]

# %%
# map genes ids to gene symbols again
cho_et_al_gene_list = cho_et_al.columns.tolist()
print("Length of cho_et_al_gene_list:", len(cho_et_al_gene_list))
print("Length of gene_id_symbol_df:", len(gene_id_symbol_df))

# Find overlap between cho_et_al_gene_list and gene_id_symbol_df["gene_id"]
gene_id_set = set(gene_id_symbol_df["gene_symbol"])
cho_et_al_gene_set = set(cho_et_al_gene_list)

# Genes in cho_et_al that are also in the GTF gene_id list
overlap_genes = cho_et_al_gene_set & gene_id_set
num_overlap = len(overlap_genes)

# Genes in cho_et_al that could not be mapped (not found in gene_id_symbol_df)
unmapped_genes = cho_et_al_gene_set - gene_id_set
num_unmapped = len(unmapped_genes)

print(f"Number of genes overlapped between cho_et_al and GTF gene_id list: {num_overlap}")
print(f"Number of genes in cho_et_al that could not be mapped: {num_unmapped}")
# Out:
# Length of cho_et_al_gene_list: 18747
# Length of gene_id_symbol_df: 63568
# Number of genes overlapped between cho_et_al and GTF gene_id list: 18745
# Number of genes in cho_et_al that could not be mapped: 0

# %%
# create a dictionary for mapping gene symbols to gene ids
map_gene_dict = dict(zip(gene_id_symbol_df["gene_symbol"], gene_id_symbol_df["gene_id_gencode19"])) # it's actually not 36 but v19 but nvm
# make a copy of cho_et_al and map the new gene names to the old gene names
cho_et_al_copy = cho_et_al.copy()
cho_et_al_copy = cho_et_al_copy.rename(columns=map_gene_dict)
cho_et_al_copy
# Out:
#         ENSG00000186092.4  ENSG00000235249.1  ENSG00000185097.2  \
# Dis_01                  2                  0                  0
# Dis_02                  0                  0                  0
# Dis_11                  0                  0                  0
# Dis_12                  0                  0                  0
# Dis_15                  0                  0                  0
# Dis_04                  0                  0                  0
# Dis_16                  0                  0                  0
# Dis_17                  0                  0                  0
# Dis_03                  6                  0                  0
# Dis_07                  0                  0                  0
# Dis_10                  1                  0                  0
# Dis_18                  0                  0                  0
# Dis_09                  0                  0                  1
# Dis_05                  0                  0                  0
# Dis_06                  1                  0                  0
# Dis_08                  0                  0                  0
#
#         ENSG00000225880.4  ENSG00000187634.6  ENSG00000188976.6  \
# Dis_01                 49                176               6343
# Dis_02                 26                 14               3154
# Dis_11                 47                  5               3656
# Dis_12                 29                  5               3656
# Dis_15                 41                 25               2665
# Dis_04                 27                 22                983
# Dis_16                 59                 28               4853
# Dis_17                 43                 69               2553
# Dis_03                 39                 62               2609
# Dis_07                 29                 40               2100
# Dis_10                 24                 48               1105
# Dis_18                 24                  9               2003
# Dis_09                 39                 20               2332
# Dis_05                 69                115               1371
# Dis_06                 24                  7               2867
# Dis_08                 37                 15               1249
#
#         ENSG00000187961.9  ENSG00000187583.6  ENSG00000188290.6  \
# Dis_01                339                 86                 59
# Dis_02                 59                 18                 50
# Dis_11                 81                  5                 16
# Dis_12                362                625                301
# Dis_15                279                139                 79
# Dis_04                133                 25                 19
# Dis_16                228                235                387
# Dis_17                220                 96                325
# Dis_03                139                143                192
# Dis_07                 80                 27                 47
# Dis_10                142                 72                114
# Dis_18                198                265                 77
# Dis_09                240                215                 86
# Dis_05                309                161                150
# Dis_06                191                109                 54
# Dis_08                134                131                137
#
#         ENSG00000187608.5  ...  ENSG00000169789.6  ENSG00000183753.5  \
# Dis_01                 52  ...                  0                  0
# Dis_02                 43  ...                  0                  0
# Dis_11                 29  ...                  0                  0
# Dis_12               1232  ...                  0                  0
# Dis_15                140  ...                  0                  0
# Dis_04                 76  ...                  0                  0
# Dis_16                248  ...                  0                  0
# Dis_17                104  ...                  0                  0
# Dis_03                380  ...                  0                  0
# Dis_07                 33  ...                  0                  0
# Dis_10                269  ...                  0                  0
# Dis_18                240  ...                  0                  0
# Dis_09                243  ...                  0                  0
# Dis_05                 57  ...                  0                  0
# Dis_06                132  ...                  0                  0
# Dis_08                245  ...                  0                  0
#
#         ENSG00000188120.10  ENSG00000205944.7  ENSG00000172352.5  \
# Dis_01                   8                388                  0
# Dis_02                   0                  0                  0
# Dis_11                  11                 31                  0
# Dis_12                   0                  0                  0
# Dis_15                   0                  0                  0
# Dis_04                   0                  0                  0
# Dis_16                   0                  0                  0
# Dis_17                   0                  0                  0
# Dis_03                   0                  0                  0
# Dis_07                   0                  0                  0
# Dis_10                   0                  5                  0
# Dis_18                   0                  0                  0
# Dis_09                   0                  0                  0
# Dis_05                   0                  0                  0
# Dis_06                   0                  0                  0
# Dis_08                   0                  0                  0
#
#         ENSG00000183795.4  ENSG00000187191.10  ENSG00000205916.6  \
# Dis_01                  0                  14                  8
# Dis_02                  0                   0                  0
# Dis_11                  0                 161                 21
# Dis_12                  0                   0                  0
# Dis_15                  0                   0                  0
# Dis_04                  0                   0                  0
# Dis_16                  0                   0                  0
# Dis_17                  0                   0                  0
# Dis_03                  0                   0                  1
# Dis_07                  0                   0                  0
# Dis_10                  0                   1                  2
# Dis_18                  0                   0                  0
# Dis_09                  0                  15                 14
# Dis_05                  0                   0                  0
# Dis_06                  0                   0                  0
# Dis_08                  0                   0                  0
#
#         ENSG00000185894.4  ENSG00000172288.6
# Dis_01                  0                  0
# Dis_02                  0                  0
# Dis_11                  0                  0
# Dis_12                  0                  0
# Dis_15                  0                  0
# Dis_04                  0                  0
# Dis_16                  0                  0
# Dis_17                  0                  0
# Dis_03                  0                  0
# Dis_07                  0                  0
# Dis_10                  0                  0
# Dis_18                  0                  0
# Dis_09                  0                  0
# Dis_05                  0                  0
# Dis_06                  0                  0
# Dis_08                  0                  0
#
# [16 rows x 18747 columns]

# %%
# go through the tpm process using the new gene names 
tpm = TPM(gtf_path).set_output(transform="pandas")
tmm = TMM(m_trim = 0.3, a_trim = 0.05).set_output(transform="pandas")


## counts, TPM, TMM
df_counts = cho_et_al_copy
df_tpm = tpm.fit_transform(df_counts)
df_tmm = tmm.fit_transform(df_counts)
df_tpm
# Out:
#         ENSG00000186092.4  ENSG00000235249.1  ENSG00000185097.2  \
# Dis_01           0.437141                0.0           0.000000
# Dis_02           0.000000                0.0           0.000000
# Dis_11           0.000000                0.0           0.000000
# Dis_12           0.000000                0.0           0.000000
# Dis_15           0.000000                0.0           0.000000
# Dis_04           0.000000                0.0           0.000000
# Dis_16           0.000000                0.0           0.000000
# Dis_17           0.000000                0.0           0.000000
# Dis_03           1.414224                0.0           0.000000
# Dis_07           0.000000                0.0           0.000000
# Dis_10           0.168790                0.0           0.000000
# Dis_18           0.000000                0.0           0.000000
# Dis_09           0.000000                0.0           0.243158
# Dis_05           0.000000                0.0           0.000000
# Dis_06           0.257780                0.0           0.000000
# Dis_08           0.000000                0.0           0.000000
#
#         ENSG00000225880.4  ENSG00000187634.6  ENSG00000188976.6  \
# Dis_01           7.465255          11.018411         229.772298
# Dis_02           4.308439           0.953306         124.268974
# Dis_11           7.384866           0.322829         136.585742
# Dis_12           4.983619           0.353081         149.385156
# Dis_15           6.737979           1.688276         104.135167
# Dis_04           4.266572           1.428551          36.933737
# Dis_16           8.233503           1.605641         161.026498
# Dis_17           5.639105           3.718336          79.606216
# Dis_03           6.407496           4.185749         101.918312
# Dis_07           3.944669           2.235786          67.918212
# Dis_10           2.823672           2.320609          30.911473
# Dis_18           4.835113           0.745067          95.946849
# Dis_09           7.164585           1.509782         101.861335
# Dis_05          14.764173          10.111501          69.751237
# Dis_06           4.312380           0.516846         122.486407
# Dis_08           8.142882           1.356518          65.357177
#
#         ENSG00000187961.9  ENSG00000187583.6  ENSG00000188290.6  \
# Dis_01          20.035226           6.090966          10.588746
# Dis_02           3.792666           1.386623           9.760242
# Dis_11           4.937144           0.365220           2.961479
# Dis_12          24.132450          49.930517          60.933667
# Dis_15          17.786725          10.619396          15.293851
# Dis_04           8.152916           1.836515           3.536819
# Dis_16          12.342794          15.245431          63.619109
# Dis_17          11.192070           5.852645          50.207557
# Dis_03           8.858996          10.921920          37.159421
# Dis_07           4.221322           1.707322           7.531030
# Dis_10           6.480930           3.937991          15.799809
# Dis_18          15.474141          24.818780          18.273850
# Dis_09          17.103447          18.361327          18.610962
# Dis_05          25.648651          16.014933          37.809008
# Dis_06          13.313283           9.104823          11.429929
# Dis_08          11.440032          13.402535          35.517384
#
#         ENSG00000187608.5  ...  ENSG00000169789.6  ENSG00000183753.5  \
# Dis_01          14.674661  ...                0.0                0.0
# Dis_02          13.198703  ...                0.0                0.0
# Dis_11           8.440321  ...                0.0                0.0
# Dis_12         392.169425  ...                0.0                0.0
# Dis_15          42.617700  ...                0.0                0.0
# Dis_04          22.245649  ...                0.0                0.0
# Dis_16          64.106269  ...                0.0                0.0
# Dis_17          25.263369  ...                0.0                0.0
# Dis_03         115.644106  ...                0.0                0.0
# Dis_07           8.314625  ...                0.0                0.0
# Dis_10          58.623463  ...                0.0                0.0
# Dis_18          89.561792  ...                0.0                0.0
# Dis_09          82.689212  ...                0.0                0.0
# Dis_05          22.591813  ...                0.0                0.0
# Dis_06          43.933510  ...                0.0                0.0
# Dis_08          99.875438  ...                0.0                0.0
#
#         ENSG00000188120.10  ENSG00000205944.7  ENSG00000172352.5  \
# Dis_01            0.348347          18.700776                0.0
# Dis_02            0.000000           0.000000                0.0
# Dis_11            0.493982           1.540940                0.0
# Dis_12            0.000000           0.000000                0.0
# Dis_15            0.000000           0.000000                0.0
# Dis_04            0.000000           0.000000                0.0
# Dis_16            0.000000           0.000000                0.0
# Dis_17            0.000000           0.000000                0.0
# Dis_03            0.000000           0.000000                0.0
# Dis_07            0.000000           0.000000                0.0
# Dis_10            0.000000           0.186103                0.0
# Dis_18            0.000000           0.000000                0.0
# Dis_09            0.000000           0.000000                0.0
# Dis_05            0.000000           0.000000                0.0
# Dis_06            0.000000           0.000000                0.0
# Dis_08            0.000000           0.000000                0.0
#
#         ENSG00000183795.4  ENSG00000187191.10  ENSG00000205916.6  \
# Dis_01                0.0            0.796447           0.371055
# Dis_02                0.0            0.000000           0.000000
# Dis_11                0.0            9.446066           1.004531
# Dis_12                0.0            0.000000           0.000000
# Dis_15                0.0            0.000000           0.000000
# Dis_04                0.0            0.000000           0.000000
# Dis_16                0.0            0.000000           0.000000
# Dis_17                0.0            0.000000           0.000000
# Dis_03                0.0            0.000000           0.050018
# Dis_07                0.0            0.000000           0.000000
# Dis_10                0.0            0.043932           0.071636
# Dis_18                0.0            0.000000           0.000000
# Dis_09                0.0            1.028959           0.782985
# Dis_05                0.0            0.000000           0.000000
# Dis_06                0.0            0.000000           0.000000
# Dis_08                0.0            0.000000           0.000000
#
#         ENSG00000185894.4  ENSG00000172288.6
# Dis_01                0.0                0.0
# Dis_02                0.0                0.0
# Dis_11                0.0                0.0
# Dis_12                0.0                0.0
# Dis_15                0.0                0.0
# Dis_04                0.0                0.0
# Dis_16                0.0                0.0
# Dis_17                0.0                0.0
# Dis_03                0.0                0.0
# Dis_07                0.0                0.0
# Dis_10                0.0                0.0
# Dis_18                0.0                0.0
# Dis_09                0.0                0.0
# Dis_05                0.0                0.0
# Dis_06                0.0                0.0
# Dis_08                0.0                0.0
#
# [16 rows x 18747 columns]

# %%
import numpy as np
df_tpm_log = np.log2(df_tpm + 1).copy()
df_tpm_log

# %%
# change the gene names back to the old ones 
map_gene_dict_back = dict(zip(gene_id_symbol_df["gene_id_gencode19"], gene_id_symbol_df["gene_id"]))

df_tpm_log_gene_id = df_tpm_log.rename(columns=map_gene_dict_back)
df_tpm_gene_id = df_tpm.rename(columns=map_gene_dict_back)
df_tpm_gene_id.shape
# Out:
# (16, 18747)

# %%
gene_id_symbol_df
# Out:
#        gene_id_gencode19 gene_symbol          gene_id
# 0      ENSG00000223972.4     DDX11L1  ENSG00000223972
# 1      ENSG00000227232.4      WASH7P  ENSG00000227232
# 2      ENSG00000243485.2  MIR1302-11  ENSG00000243485
# 3      ENSG00000237613.2     FAM138A  ENSG00000237613
# 4      ENSG00000268020.2      OR4G4P  ENSG00000268020
# ...                  ...         ...              ...
# 63563  ENSG00000241559.2  CU459202.2  ENSG00000241559
# 63564  ENSG00000264728.1  CU442762.3  ENSG00000264728
# 63565  ENSG00000238667.1  CU442762.2  ENSG00000238667
# 63566  ENSG00000238477.1  CU442762.1  ENSG00000238477
# 63567  ENSG00000271726.1  CU442762.4  ENSG00000271726
#
# [63568 rows x 3 columns]

# %%
# read compass gene mapping
compass_gene_mapping = pd.read_csv("/Users/z5155527/Desktop/Benchmark-2025-Sep/phase_1_datasets/bulk_RNA-seq/compass/compass_gene_map.csv")
compass_gene_mapping
# Out:
#                  ensid gene_name           ensid_v36       gene_type  \
# 0      ENSG00000121410      A1BG  ENSG00000121410.12  protein_coding
# 1      ENSG00000148584      A1CF  ENSG00000148584.15  protein_coding
# 2      ENSG00000175899       A2M  ENSG00000175899.15  protein_coding
# 3      ENSG00000166535     A2ML1  ENSG00000166535.20  protein_coding
# 4      ENSG00000128274    A4GALT  ENSG00000128274.17  protein_coding
# ...                ...       ...                 ...             ...
# 15667  ENSG00000203995    ZYG11A  ENSG00000203995.10  protein_coding
# 15668  ENSG00000162378    ZYG11B  ENSG00000162378.13  protein_coding
# 15669  ENSG00000159840       ZYX  ENSG00000159840.16  protein_coding
# 15670  ENSG00000074755     ZZEF1  ENSG00000074755.15  protein_coding
# 15671  ENSG00000036549      ZZZ3  ENSG00000036549.13  protein_coding
#
#        gene_supertype  entrezgene
# 0      protein_coding         1.0
# 1      protein_coding     29974.0
# 2      protein_coding         2.0
# 3      protein_coding    144568.0
# 4      protein_coding     53947.0
# ...               ...         ...
# 15667  protein_coding    440590.0
# 15668  protein_coding     79699.0
# 15669  protein_coding      7791.0
# 15670  protein_coding     23140.0
# 15671  protein_coding     26009.0
#
# [15672 rows x 6 columns]

# %%
# Try to map the columns of df_tpm_gene_id (columns are "gene_id" like "ENSG00000223972")
# to the compass gene mapping (which has an "ensid" column).

# First, create a mapping from compass_gene_mapping 'ensid' to the full row (or to its preferred symbol)
# Let's get both the sets for exploration:
tpm_gene_ids = set(df_tpm_gene_id.columns)
compass_ensids = set(compass_gene_mapping["ensid"])

# Intersect for successfully mappable genes:
common_ensids = tpm_gene_ids & compass_ensids

print(f"Number of genes in TPM data: {len(tpm_gene_ids)}")
print(f"Number of genes in compass mapping: {len(compass_ensids)}")
print(f"Number of genes successfully mapped: {len(common_ensids)}")

# For genes in compass mapping that are not present in TPM data, add columns with 0s
missing_ensids = compass_ensids - tpm_gene_ids

# Add missing columns with zeros (same order as missing_ensids set, sorted for reproducibility)
for ensid in sorted(missing_ensids):
    df_tpm_gene_id[ensid] = 0

# Now reorder the dataframe columns to match the compass_gene_mapping order (if desired)
ordered_ensids = [ensid for ensid in compass_gene_mapping["ensid"] if ensid in df_tpm_gene_id.columns]
df_tpm_gene_id_mapped = df_tpm_gene_id[ordered_ensids].copy()

# Map ensid to gene_name according to compass_gene_mapping
ensid_to_symbol = dict(zip(compass_gene_mapping["ensid"], compass_gene_mapping["gene_name"]))
df_tpm_gene_id_mapped = df_tpm_gene_id_mapped.rename(columns=ensid_to_symbol)

# Optionally: list of unmapped ensids (just for reference)
unmapped_gene_ids = tpm_gene_ids - compass_ensids
# Out:
# Number of genes in TPM data: 18745
# Number of genes in compass mapping: 15672
# Number of genes successfully mapped: 14766
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# ...
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0
# /var/folders/4k/f164lhy95glg7mpdg8pdz5_m0000gp/T/ipykernel_42843/415242716.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_tpm_gene_id[ensid] = 0

# %%
# Add Index column to df_tpm_gene_id_mapped with the current index as a column
df_tpm_gene_id_mapped["Index"] = df_tpm_gene_id_mapped.index

# %%
# clinical data
cho_et_al_clinical = pd.read_csv("/Users/z5155527/Desktop/Benchmark-2025-Sep/external_validation_datasets/bulk_rna_seq/GSE126044/cho_clinical.txt", sep='\t')
cho_et_al_clinical
# Out:
#         ID    Sentrix_ID Sentrix_Position  Age Sex                Histology  \
# 0   Dis_01  2.019600e+11           R08C01   72   M  Squamous_cell_carcinoma
# 1   Dis_02  2.014380e+11           R03C01   76   M  Squamous_cell_carcinoma
# 2   Dis_03  2.019600e+11           R01C01   65   M  Squamous_cell_carcinoma
# 3   Dis_04  2.014140e+11           R07C01   55   F           Adenocarcinoma
# 4   Dis_05  2.014140e+11           R03C01   72   M           Adenocarcinoma
# 5   Dis_06  2.014140e+11           R01C01   54   M           Adenocarcinoma
# 6   Dis_07  2.019600e+11           R04C01   66   M  Squamous_cell_carcinoma
# 7   Dis_08  2.014140e+11           R05C01   34   F           Adenocarcinoma
# 8   Dis_09  2.014140e+11           R02C01   61   M  Squamous_cell_carcinoma
# 9   Dis_10  2.019600e+11           R06C01   75   M  Squamous_cell_carcinoma
# 10  Dis_11  2.011060e+11           R01C01   47   M           Adenocarcinoma
# 11  Dis_12  2.011060e+11           R05C01   65   M  Squamous_cell_carcinoma
# 12  Dis_13  2.008640e+11           R04C01   65   M           Adenocarcinoma
# 13  Dis_14  2.011060e+11           R01C01   48   F           Adenocarcinoma
# 14  Dis_15  2.011060e+11           R07C01   58   M           Adenocarcinoma
# 15  Dis_16  2.011060e+11           R05C01   56   M           Adenocarcinoma
# 16  Dis_17  2.011060e+11           R03C01   64   M  Squamous_cell_carcinoma
# 17  Dis_18  2.011060e+11           R06C01   67   M  Squamous_cell_carcinoma
#
#    PD-L1expression Responsiveness Immunotherapy_drug  \
# 0               No  Non-responder          Nivolumab
# 1              Yes      Responder          Nivolumab
# 2              NaN  Non-responder          Nivolumab
# 3              Yes      Responder          Nivolumab
# 4               No  Non-responder          Nivolumab
# 5               No  Non-responder          Nivolumab
# 6               No  Non-responder          Nivolumab
# 7               No  Non-responder          Nivolumab
# 8              NaN  Non-responder          Nivolumab
# 9              Yes      Responder          Nivolumab
# 10              No  Non-responder          Nivolumab
# 11              No  Non-responder          Nivolumab
# 12             Yes      Responder      Pembrolizumab
# 13              No  Non-responder          Nivolumab
# 14              No      Responder          Nivolumab
# 15             Yes  Non-responder          Nivolumab
# 16              No      Responder          Nivolumab
# 17             Yes  Non-responder          Nivolumab
#
#     Progression_free_survival(month)  Overall_survival(months) Best_response
# 0                                0.5                       1.1            PD
# 1                               13.8                      14.1            PR
# 2                                2.3                      11.2            PD
# 3                               13.5                      18.7            PR
# 4                                2.8                       9.6            PD
# 5                                0.8                       0.8            PD
# 6                                1.1                       3.5            PD
# 7                                1.0                       1.0            PD
# 8                                0.7                       1.0            PD
# 9                               14.2                      14.2            PR
# 10                               2.1                       3.1            PD
# 11                               3.4                      12.7            PD
# 12                              12.0                      21.6            PR
# 13                               1.3                       5.8            PD
# 14                              17.7                      18.1            PR
# 15                               3.6                      10.2            PD
# 16                               7.3                      12.9            SD
# 17                               0.5                       1.7            PD

# %%
code_16_patients = cho_et_al_clinical.loc[cho_et_al_clinical["Histology"]=="Adenocarcinoma", "ID"]
df_tpm_gene_id_mapped.loc[df_tpm_gene_id_mapped["Index"].isin(code_16_patients), "cancer_code"] = 16
code_17_patients = cho_et_al_clinical.loc[cho_et_al_clinical["Histology"]=="Squamous_cell_carcinoma", "ID"]
df_tpm_gene_id_mapped.loc[df_tpm_gene_id_mapped["Index"].isin(code_17_patients), "cancer_code"] = 17
df_tpm_gene_id_mapped
# Out:
#              A1BG      A1CF          A2M       A2ML1      A4GALT     A4GNT  \
# Dis_01   1.853212  0.083577   130.590766   16.155126   22.294196  0.000000
# Dis_02   4.467199  0.136357   596.157603    0.627553   37.596731  0.369688
# Dis_11   2.892728  0.043098   445.762500   28.137045    8.226709  0.116845
# Dis_12   4.067749  0.047136   492.710767  746.689818  151.652395  0.511180
# Dis_15   6.321301  0.315539   855.645021    9.839394   32.579546  3.055294
# Dis_04   4.519698  0.000000   834.802765    0.911905   11.031522  1.527657
# Dis_16   1.192836  0.038277   446.573902    0.125831   59.764061  0.000000
# Dis_17   8.062286  0.035971  2649.688076    3.476511  144.309791  0.097523
# Dis_03   8.426033  0.540772   165.535935    3.436894   22.130221  1.466129
# Dis_07   5.589814  0.093274  2566.753210    0.637779   28.791825  0.101153
# Dis_10   3.481131  0.048406   186.259189    0.700167   16.953306  0.174985
# Dis_18   5.762215  0.138148   470.098922  137.731607   44.807143  2.097445
# Dis_09   4.227652  0.050389   324.371231  380.687577   54.669306  1.502749
# Dis_05  15.405613  0.381489  2875.283666    1.620667  121.990213  2.705056
# Dis_06   4.371317  0.049285   413.159487   11.081955   23.318430  0.400861
# Dis_08   2.387620  0.030183   453.832488    0.555634   11.719765  2.291246
#
#               AAAS       AACS      AADAC      AADAT  ...       ZXDA  \
# Dis_01  249.039852   9.852181   1.443509  36.952573  ...   4.433992
# Dis_02  137.230041  19.749891   6.411098   6.881740  ...   5.493718
# Dis_11  207.433457  35.074108   0.868425  53.034921  ...   6.680401
# Dis_12  115.022131  14.432811  17.910615  11.843914  ...   6.262645
# Dis_15  128.303538   9.134237  15.700768   7.841395  ...  10.189676
# Dis_04   88.013372   3.945226   0.124769   3.141605  ...   5.678742
# Dis_16  114.767902  12.485603   0.330555   9.247998  ...   5.226884
# Dis_17  146.210035   8.931447   5.591460  19.177569  ...  15.864199
# Dis_03   65.153397   7.464031   6.096932  38.252352  ...  12.473648
# Dis_07   52.340049   6.123954   2.255390  16.405859  ...   5.266868
# Dis_10   37.258158   1.945410   1.579216   1.767282  ...   3.007273
# Dis_18  125.994968   9.960681  63.309394  18.513243  ...  10.349989
# Dis_09  138.511794  23.819811  16.100491   8.684283  ...  14.551884
# Dis_05  222.827420  13.872092  14.698365  40.743761  ...  21.281444
# Dis_06  141.081553  14.017011   0.141872   5.715603  ...   5.502242
# Dis_08  126.429649  31.111826   0.521300  18.959848  ...  15.260736
#
#              ZXDB       ZXDC     ZYG11A     ZYG11B         ZYX       ZZEF1  \
# Dis_01  10.285066  34.773127  10.558159  13.586671   19.707506   46.579396
# Dis_02   3.174104  49.657755   6.834498  15.336002   90.191252   49.659753
# Dis_11   8.478469  70.712316  17.854286  14.113103   62.044355   86.693590
# Dis_12  11.079410  35.900684  12.921839  14.911929   88.008075   38.542822
# Dis_15  13.820030  30.125258   2.582121  18.636096  191.511343   71.386871
# Dis_04   7.161067  18.641710   0.576370  16.576117  311.393866   64.893056
# Dis_16  12.843683  13.914668   7.439246   8.707069  226.542333   36.762337
# Dis_17  17.032455  30.800702   1.030250  13.630334  160.958333   73.271285
# Dis_03  13.816147  18.999461   1.152408   8.722509   35.358433   16.407416
# Dis_07   7.594010  12.028861   0.419805  12.152271   85.146646   42.749114
# Dis_10   4.287344  10.867702   0.561170   3.679827  146.761004   41.923474
# Dis_18  18.494756  35.126860   8.704799  18.289486   75.361348   58.970796
# Dis_09  16.993479  49.657903  12.215674  29.171000  121.388157   75.273712
# Dis_05  19.243386  57.111387   5.162989  26.598153  160.486967  142.374654
# Dis_06   9.905548  34.063304   7.763708   9.885295   96.981026   70.107275
# Dis_08  13.623322  40.657545   7.965423  50.230912   58.018464   44.558873
#
#              ZZZ3   Index  cancer_code
# Dis_01  51.253386  Dis_01         17.0
# Dis_02  31.374281  Dis_02         17.0
# Dis_11  34.963654  Dis_11         16.0
# Dis_12  24.421397  Dis_12         17.0
# Dis_15  30.034002  Dis_15         16.0
# Dis_04   9.818873  Dis_04         16.0
# Dis_16   9.018043  Dis_16         16.0
# Dis_17  22.452052  Dis_17         17.0
# Dis_03  36.871390  Dis_03         17.0
# Dis_07  19.926804  Dis_07         17.0
# Dis_10   6.966513  Dis_10         17.0
# Dis_18  28.777119  Dis_18         17.0
# Dis_09  48.828983  Dis_09         17.0
# Dis_05  35.725931  Dis_05         16.0
# Dis_06  28.004021  Dis_06         16.0
# Dis_08  26.030491  Dis_08         16.0
#
# [16 rows x 15674 columns]

# %%
df_tpm_gene_id_mapped = df_tpm_gene_id_mapped[compass_example_data_genelist]


df_tpm_gene_id_mapped.to_csv("/Users/z5155527/Desktop/Benchmark-2025-Sep/external_validation_datasets/bulk_rna_seq/GSE126044/cho_et_al_cleaned_TPM.tsv", sep='\t', index=False)

# %%
# change the gene names back to the old ones 
map_gene_dict_back = dict(zip(gene_id_symbol_df["gene_id_gencode19"], gene_id_symbol_df["gene_symbol"]))

cho_et_al_tpm_log = df_tpm_log.rename(columns=map_gene_dict_back)

cho_et_al_tpm = df_tpm.rename(columns=map_gene_dict_back)
cho_et_al_tpm

# %%
len(map_gene_dict_back)
# Out:
# 63568

# %%
cho_et_al_tpm_log.to_csv('/Users/z5155527/Desktop/Benchmark-2025-Sep/phase_1_datasets/bulk_RNA-seq/cho_et_al_tpm_log.tsv', sep='\t')
cho_et_al_tpm.to_csv('/Users/z5155527/Desktop/Benchmark-2025-Sep/phase_1_datasets/bulk_RNA-seq/cho_et_al_tpm.tsv', sep='\t')

# %%
pd.DataFrame(unmapped_genes).to_csv("/Users/z5155527/Desktop/Benchmark-2025-Sep/external_validation_datasets/bulk_rna_seq/GSE126044/unmapped_genes.txt", sep='\t', index=False)

# %%
# firstly, compare the two gene lists and look for which genes are in compass example data but not in our data
cho_et_al_columns = cho_et_al_tpm.columns.tolist()
gene_list = list(set(compass_example_data_genelist) - set(cho_et_al_columns))
gene_list
# Out:
# ['SAMD1',
#  'CENPU',
#  'C19orf84',
#  'SF3B6',
#  'AK6',
#  'RFX7',
#  'RYBP',
#  'FTCDNL1',
#  'GGT2',
#  'ANKRD36C',
#  'PLSCR3',
#  'C3orf49',
#  'NEURL1',
#  'LKAAEAR1',
#  'JADE2',
#  'CEBPZOS',
#  'C8orf88',
#  'AZI2',
#  'RAB29',
#  'NAA38',
#  'MS4A4E',
#  'PIDD1',
#  'ARPIN',
#  'SMIM24',
#  'CCDC184',
#  'TMIGD3',
#  'MTERF3',
#  'GCNT7',
#  'RSRP1',
#  'ERVMER34-1',
#  'ZNF670-ZNF695',
#  'GCKR',
#  'MTURN',
#  'MUC2',
#  'CEP131',
#  'NOL4L',
#  'NPIPB5',
#  'LRRC75B',
#  'LHFPL4',
#  'CIPC',
#  'ERICH3',
#  'MAST1',
#  'PRMT9',
#  'RPEL1',
#  'LRRC75A',
#  'PRR29',
#  'OTULIN',
#  'HGH1',
#  'SARAF',
#  'ICE2',
#  'NIFK',
#  'ERICH5',
#  'TMEM262',
#  'MYO15B',
#  'ZNF738',
#  'NPIPB11',
#  'RITA1',
#  'MTERF1',
#  'MALRD1',
#  'COL6A5',
#  'ANKRD18B',
#  'CXCL8',
#  'PROSER3',
#  'CAD',
#  'ACKR1',
#  'SLC37A4',
#  'ZPR1',
#  'LMNTD1',
#  'NPIPB4',
#  'CT55',
#  'ZBED9',
#  'TMEM263',
#  'HMCN2',
#  'KDF1',
#  'CEP162',
#  'SPATA45',
#  'NAPRT',
#  'MTCL1',
#  'Index',
#  'DRICH1',
#  'cancer_code',
#  'CCDC185',
#  'ZNF598',
#  'NT5DC4',
#  'ATG101',
#  'C1orf167',
#  'MCEMP1',
#  'ZNF852',
#  'CEMIP',
#  'ZCCHC8',
#  'RTP5',
#  'ZGRF1',
#  'MTERF2',
#  'DDIAS',
#  'CIART',
#  'FOXO6',
#  'PERM1',
#  'ERICH6',
#  'NWD2',
#  'MTERF4',
#  'PXYLP1',
#  'NBPF1',
#  'ICE1',
#  'LMNTD2',
#  'CCDC186',
#  'ZDHHC11B',
#  'JADE1',
#  'STBD1',
#  'MUC19',
#  'REC114',
#  'IL25',
#  'CCDC154',
#  'KDM7A',
#  'SUGCT',
#  'ERICH4',
#  'IL27',
#  'MROH8',
#  'PRB3',
#  'IFT22',
#  'CEP83',
#  'COA7',
#  'JADE3',
#  'NIM1K',
#  'CYSRT1',
#  'FBLL1',
#  'MRPL57',
#  'SPX',
#  'ZBED8',
#  'CPTP',
#  'EDRF1',
#  'RNF212B',
#  'ASXL2',
#  'STKLD1',
#  'CLASP2',
#  'VSIR']

# %%
gene_list_with_synoy[gene_list_with_synoy["Symbol"]=="PIDD1"]
# Out:
#       Symbol Synonyms_separated
# 12765  PIDD1               LRDD
# 12765  PIDD1              MRT75
# 12765  PIDD1               PIDD

# %%
cho_et_al_tpm["PIDD"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/miniconda3/envs/precise_env/lib/python3.8/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File /opt/miniconda3/envs/precise_env/lib/python3.8/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/miniconda3/envs/precise_env/lib/python3.8/site-packages/pandas/_libs/index.pyx:171, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/miniconda3/envs/precise_env/lib/python3.8/site-packages/pandas/_libs/index.pyx:214, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File /opt/miniconda3/envs/precise_env/lib/python3.8/site-packages/pandas/_libs/index.pyx:222, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File /opt/miniconda3/envs/precise_env/lib/python3.8/site-packages/pandas/_libs/index.pyx:114, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'PIDD'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 cho_et_al_tpm["PIDD"]
#
# File /opt/miniconda3/envs/precise_env/lib/python3.8/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File /opt/miniconda3/envs/precise_env/lib/python3.8/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'PIDD'

# %%
# then map this gene list to synonym
gene_list_df1_1 = gene_list_with_synoy[gene_list_with_synoy["Symbol"].isin(gene_list)]
gene_list_df1_1
# Out:
#       Symbol Synonyms_separated
# 645      CAD              CDG1Z
# 645      CAD              DEE50
# 645      CAD             EIEE50
# 645      CAD              GATD4
# 2040   ACKR1              CCBP1
# ...      ...                ...
# 40885    AK6             AD-004
# 40885    AK6            CGI-137
# 40885    AK6              CINAP
# 40885    AK6                CIP
# 40885    AK6             hCINAP
#
# [301 rows x 2 columns]

# %%
gene_list_2_1 = list(set(gene_list) - set(gene_list_df1_1["Symbol"]))
print("length of gene_list_2_1", len(gene_list_2_1))
# then map this gene list to synonym
gene_list_df2_1 = gene_list_with_synoy[gene_list_with_synoy["Synonyms_separated"].isin(gene_list_2_1)]
gene_list_df2_1
# Out:
# length of gene_list_2_1 5
#              Symbol Synonyms_separated
# 14017       FAM200C              ZBED8
# 17075        SCAND3              ZBED9
# 27751         GGT2P               GGT2
# 41677  LOC102724197               GGT2

# %%
gene_list_2_1
# Out:
# ['Index', 'ZBED9', 'cancer_code', 'ZBED8', 'GGT2']

# %%
set(cho_et_al_tpm.columns.tolist())
# Out:
# {'RPL15',
#  'SRGAP2',
#  'APITD1-CORT',
#  'DKK2',
#  'CRH',
#  'CCNY',
#  'ZC3H13',
#  'NAA16',
#  'DNAAF3',
#  'FAM181B',
#  'PSPH',
#  'ACAP2',
#  'ZSCAN30',
#  'SENP2',
#  'B4GALT7',
#  'HELB',
#  'IMMP2L',
#  'HTT',
#  'FMOD',
#  'CNGB1',
#  'PHKG1',
#  'NDUFB1',
#  'GAPDHS',
#  'SPICE1',
#  'MYF5',
#  'CD200R1L',
#  'PF4V1',
#  'ZSCAN1',
#  'SRRT',
#  'SPCS3',
#  'TEX12',
#  'C8orf74',
#  'KBTBD6',
#  'AKNAD1',
#  'LARP4B',
#  'SFXN5',
#  'FMO5',
#  'PSMB7',
#  'SDCCAG3',
#  'NVL',
#  'NODAL',
#  'PRB4',
#  'OR3A1',
#  'LAMTOR4',
#  'OXSM',
#  'ACTR1A',
#  'NR5A2',
#  'LAT2',
#  'GMEB2',
#  'LSM1',
#  'PRMT2',
#  'PDE7A',
#  'ALS2CR11',
#  'SCN8A',
#  'RIPK4',
#  'PTPRK',
#  'SMCHD1',
#  'RBMXL3',
#  'SPTAN1',
#  'SLC25A19',
#  'LCA5L',
#  'LRRC58',
#  'UFM1',
#  'CCDC69',
#  'BTC',
#  'KIAA1143',
#  'PLAC8',
#  'SLITRK6',
#  'GEMIN2',
#  'BCOR',
#  'B3GAT1',
#  'NPIPA3',
#  'AQP4',
#  'THNSL1',
#  'CDKL1',
#  'UBE2NL',
#  'ZMYND11',
#  'NCKAP1',
#  'TRAF2',
#  'C2orf66',
#  'MTHFD2L',
#  'FASTKD1',
#  'YAF2',
#  'MUT',
#  'EPO',
#  'NRN1L',
#  'DDX60L',
#  'PCDHB10',
#  'ANO2',
#  'ANO6',
#  'OSBPL6',
#  'CNOT1',
#  'DSG1',
#  'EBAG9',
#  'UPK1B',
#  'FAM104A',
#  'TXNIP',
#  'ARHGDIG',
#  'PIK3CG',
#  'GUCA1A',
#  'EBF3',
#  'ZNF562',
#  'BANP',
#  'OR2A5',
#  'TMEM74B',
#  'CPNE3',
#  'GAS2',
#  'MZT2B',
#  'DUSP3',
#  'SYN1',
#  'CPSF6',
#  'FADS2',
#  'CYP4X1',
#  'USP13',
#  'MMP21',
#  'SEMA5A',
#  'NKX2-5',
#  'AKAP14',
#  'PACSIN1',
#  'C1QB',
#  'SPAG6',
#  'AURKAIP1',
#  'OR4C3',
#  'MMP14',
#  'WIPI1',
#  'DSN1',
#  'SNX8',
#  'TCF7L1',
#  'C7orf61',
#  'TTC39A',
#  'ACBD5',
#  'STX18',
#  'CD2BP2',
#  'GFRA3',
#  'DPEP2',
#  'MIOX',
#  'TUBA3D',
#  'AGBL3',
#  'FLT4',
#  'MRPL51',
#  'TMEM253',
#  'STRADB',
#  'TGM3',
#  'MOSPD2',
#  'ZNF572',
#  'C9orf142',
#  'PSMG2',
#  'GNA15',
#  'GNRH2',
#  'SRRD',
#  'CCPG1',
#  'HLF',
#  'ANAPC4',
#  'TSPAN15',
#  'USP6NL',
#  'MTBP',
#  'DUSP21',
#  'CCDC82',
#  'PMAIP1',
#  'C1orf116',
#  'OXSR1',
#  'PITPNA',
#  'WDR59',
#  'COL16A1',
#  'PAPD7',
#  'TTC39C',
#  'NDUFB8',
#  'SH2B1',
#  'CDK5RAP1',
#  'TTC16',
#  'ZNF510',
#  'NBAS',
#  'SLC25A3',
#  'ZNF770',
#  'FAM46D',
#  'PISD',
#  'LINC00299',
#  'TTLL3',
#  'OR4F3',
#  'ORC5',
#  'ZNF236',
#  'ARPC4-TTLL3',
#  'ETNPPL',
#  'DYNC2H1',
#  'DDX10',
#  'SPARC',
#  'SLC9C2',
#  'MAD2L2',
#  'TMEM252',
#  'RPS6KA6',
#  'PDCD6IP',
#  'ZBP1',
#  'SLC22A18',
#  'SMCO1',
#  'ARMC5',
#  'GLI1',
#  'CCDC9',
#  'TTC27',
#  'EZH1',
#  'LYRM4',
#  'RGS2',
#  'CLPB',
#  'KRTAP25-1',
#  'PRKG2',
#  'ZNF672',
#  'AFF4',
#  'NUCB2',
#  'TMEM150C',
#  'WBP2NL',
#  'RUNDC1',
#  'SYNPO2L',
#  'RSRC2',
#  'TTYH2',
#  'TMEM120A',
#  'CDH17',
#  'AP3M1',
#  'EPS8L1',
#  'GOLPH3L',
#  'MSH6',
#  'IL20RA',
#  'GTF3C6',
#  'BRAF',
#  'KRT31',
#  'SLC11A2',
#  'SLC35E4',
#  'CSMD1',
#  'CHCHD3',
#  'DYTN',
#  'RPL3',
#  'SH3KBP1',
#  'SDSL',
#  'G6PC3',
#  'QRSL1',
#  'TIMP2',
#  'SNRPD3',
#  'KIF19',
#  'CCDC51',
#  'MAPK11',
#  'CABIN1',
#  'DCSTAMP',
#  'NEK3',
#  'MEIOB',
#  'AFAP1L2',
#  'HIGD1C',
#  'TMEM161A',
#  'ZNF7',
#  'GPRC5D',
#  'DGKD',
#  'MLIP',
#  'IPCEF1',
#  'HEPACAM2',
#  'CTSL',
#  'TRIM48',
#  'GFPT1',
#  'KIF5A',
#  'MEX3C',
#  'KCNJ6',
#  'CHADL',
#  'CHST11',
#  'CFHR5',
#  'SKI',
#  'FAM60A',
#  'TIGD1',
#  'CD300E',
#  'ZNHIT6',
#  'CLDN3',
#  'OR52I2',
#  'SLC46A2',
#  'PARP16',
#  'NRXN2',
#  'RD3L',
#  'BRK1',
#  'ACAN',
#  'AHSP',
#  'CTDSP2',
#  'RNMT',
#  'CIRBP',
#  'TMPRSS12',
#  'SLC22A11',
#  'NANS',
#  'PSMG3',
#  'KLK4',
#  'STH',
#  'MARS',
#  'GLB1L',
#  'GATC',
#  'NARS2',
#  'SIAH3',
#  'C6orf118',
#  'ENG',
#  'CTCFL',
#  'FADS6',
#  'AVPR2',
#  'ZNF226',
#  'HLA-B',
#  'BEGAIN',
#  'LGALSL',
#  'EPHA10',
#  'PODN',
#  'SUMO1',
#  'PSMD9',
#  'RNF168',
#  'ZNF165',
#  'IRX2',
#  'SIGLEC6',
#  'PPIP5K1',
#  'LACTB',
#  'MPND',
#  'RING1',
#  'GPR155',
#  'SPATA3',
#  'PCM1',
#  'ISPD',
#  'MOK',
#  'FAM160A2',
#  'NADSYN1',
#  'MORN3',
#  'GGACT',
#  'CYTH4',
#  'XAGE1C',
#  'ABCF1',
#  'KNSTRN',
#  'NHSL2',
#  'ZNF449',
#  'TMEM185A',
#  'WDR77',
#  'FBXW2',
#  'PHF2',
#  'ENOSF1',
#  'ACSL6',
#  'SLC4A11',
#  'SPATA19',
#  'PIM3',
#  'ZNF445',
#  'CMTM5',
#  'ABHD6',
#  'RPS14',
#  'YPEL2',
#  'CCDC144A',
#  'CBY1',
#  'PCDHA10',
#  'FBXW4',
#  'SCNN1D',
#  'METTL21A',
#  'DDB2',
#  'SLC22A9',
#  'DDX25',
#  'MSRB1',
#  'RAB11FIP4',
#  'COX6A2',
#  'ABCC5',
#  'MFSD7',
#  'TMEM251',
#  'TARM1',
#  'TGM2',
#  'OR10J3',
#  'RIOK1',
#  'MLX',
#  'OR7E24',
#  'MACC1',
#  'TBC1D2B',
#  'ZNF587B',
#  'RAD52',
#  'DUX4L7',
#  'PLA2G2A',
#  'PEX3',
#  'FCRL6',
#  'SLC17A4',
#  'CHRNB1',
#  'KIF13A',
#  'RAB11FIP1',
#  'RNF8',
#  'AIG1',
#  'IGF2R',
#  'SOX3',
#  'ANHX',
#  'CBLN4',
#  'ARMCX1',
#  'IFI6',
#  'CDPF1',
#  'GOLGA7',
#  'CA2',
#  'DTWD1',
#  'GATA4',
#  'AKR1C4',
#  'GH2',
#  'OR5D16',
#  'HMGN2',
#  'F2R',
#  'ARHGEF2',
#  'HIST2H2BE',
#  'ASTL',
#  'SCAP',
#  'SERPINH1',
#  'ZNF675',
#  'EFNB1',
#  'DUOXA1',
#  'CT47A3',
#  'TOP2B',
#  'GNG12',
#  'SMAP1',
#  'HOXA5',
#  'PRY',
#  'IL18BP',
#  'LCE2A',
#  'MEGF10',
#  'KCNE3',
#  'DNASE1L1',
#  'TSPAN12',
#  'SYCE1',
#  'PAFAH1B1',
#  'SNX11',
#  'ZNF580',
#  'FOXN4',
#  'PAK4',
#  'TM9SF2',
#  'DGCR6',
#  'RNF2',
#  'FANCE',
#  'PXK',
#  'KHDRBS3',
#  'TMC3',
#  'C7orf49',
#  'GZMB',
#  'LRRC7',
#  'GLRX2',
#  'C1QTNF2',
#  'CELA1',
#  'SNW1',
#  'MOB2',
#  'P2RX4',
#  'GPANK1',
#  'CMC1',
#  'ZNF334',
#  'CELSR2',
#  'PRDM4',
#  'FLYWCH2',
#  'C8orf48',
#  'SMG7',
#  'VPS26B',
#  'PRKD2',
#  'VN1R2',
#  'GALNT5',
#  'TTC26',
#  'ZAR1L',
#  'PEX19',
#  'PRR21',
#  'MYO6',
#  'ZSWIM1',
#  'TRIM58',
#  'RAB6B',
#  'LHFPL5',
#  'PPP2R2A',
#  'SPAST',
#  'DENND2D',
#  'MCOLN2',
#  'SPEF2',
#  'MAPKAP1',
#  'ZNF136',
#  'SAMM50',
#  'NEO1',
#  'TNC',
#  'OPN1MW2',
#  'GSTM1',
#  'UNC13D',
#  'JUND',
#  'SVOP',
#  'LOXL4',
#  'HERC3',
#  'DMRTB1',
#  'ENTPD4',
#  'CA1',
#  'FRMD8',
#  'MAML2',
#  'RCAN1',
#  'TAS1R1',
#  'ABCD4',
#  'SLC6A20',
#  'HMGB1',
#  'LACC1',
#  'C14orf2',
#  'GABRB3',
#  'LIPJ',
#  'MAGED2',
#  'CRLF1',
#  'DRGX',
#  'SLC6A15',
#  'TMEM41B',
#  'LRRC36',
#  'ZNF549',
#  'IFI44',
#  'RAB4B',
#  'HIST1H2AH',
#  'DIXDC1',
#  'HORMAD1',
#  'ANAPC16',
#  'KCTD12',
#  'ZNF594',
#  'BLVRB',
#  'ZNF678',
#  'PEX2',
#  'EIF1',
#  'ATP6V0E2',
#  'KRTAP2-3',
#  'VPS37D',
#  'GDF7',
#  'CHODL',
#  'GPCPD1',
#  'CAMK2B',
#  'GSTO2',
#  'ZNF655',
#  'OR51B6',
#  'KCNB1',
#  'KRTAP26-1',
#  'OCM',
#  'CDC27',
#  'NDC80',
#  'GPR132',
#  'GPRIN2',
#  'ATP2B2',
#  'ACOT2',
#  'EXD1',
#  'FRMD4A',
#  'MAP1LC3B',
#  'IL17REL',
#  'LAMP5',
#  'EGLN3',
#  'ENO4',
#  'PBXIP1',
#  'CLEC4D',
#  'FN3K',
#  'SHE',
#  'GSS',
#  'DPCD',
#  'GSE1',
#  'ZNF681',
#  'SLC22A2',
#  'OR52E4',
#  'FCGRT',
#  'PGBD2',
#  'GABRG1',
#  'XPO7',
#  'METRN',
#  'KHSRP',
#  'TSPAN14',
#  'DEFB105A',
#  'EIF5AL1',
#  'SPANXN1',
#  'SIGLEC12',
#  'HEATR5B',
#  'B3GALT6',
#  'HP',
#  'CT47A4',
#  'FAM214A',
#  'HFE',
#  'MYO1G',
#  'OR6C68',
#  'LRRK1',
#  'TDRD7',
#  'MGAT2',
#  'MAGEB16',
#  'NDUFA13',
#  'ZNF267',
#  'ELOVL6',
#  'NFATC1',
#  'RPL30',
#  'RASSF10',
#  'SLCO5A1',
#  'CPT1C',
#  'NDUFV1',
#  'SLC7A11',
#  'TBC1D13',
#  'KDM6A',
#  'MAN2A1',
#  'DUSP22',
#  'DDR1',
#  'STARD6',
#  'MRI1',
#  'NPY5R',
#  'EIF4A3',
#  'SPANXN2',
#  'MRRF',
#  'AASDHPPT',
#  'SMARCE1',
#  'CINP',
#  'MAP3K8',
#  'PRG4',
#  'SOX7',
#  'FCN2',
#  'C17orf112',
#  'PCDHB3',
#  'MRPL22',
#  'ID2',
#  'XKR4',
#  'GTF3A',
#  'MORC2-AS1',
#  'FNIP2',
#  'MYCT1',
#  'CRYGN',
#  'SLC33A1',
#  'PPP4C',
#  'CD2',
#  'RB1',
#  'IL5',
#  'ZER1',
#  'RGAG4',
#  'USP12',
#  'EAF2',
#  'PCDH1',
#  'OR52E8',
#  'ATOX1',
#  'SLCO1B1',
#  'TBRG1',
#  'CKAP2L',
#  'ZBTB44',
#  'DIO2',
#  'FRMPD3',
#  'SDCBP2',
#  'ZNF626',
#  'RFX3',
#  'SMARCA2',
#  'TSPY1',
#  'TTC30B',
#  'SLC34A2',
#  'BAIAP2L2',
#  'DDTL',
#  'ERBB3',
#  'FAM166A',
#  'WRB',
#  'SZT2',
#  'SNX19',
#  'TINCR',
#  'CYP3A4',
#  'PNOC',
#  'DPP6',
#  'VCPIP1',
#  'CHI3L2',
#  'LIMA1',
#  'MOB4',
#  'KLF1',
#  'ZNF829',
#  'CACNA1D',
#  'FAM198B',
#  'LINC00472',
#  'RTN4IP1',
#  'CGB5',
#  'GAL3ST3',
#  'NPRL2',
#  'FABP6',
#  'C9orf153',
#  'CT47A8',
#  'HOPX',
#  'SRRM3',
#  'IFNA13',
#  'CLHC1',
#  'KCNIP1',
#  'FRMD1',
#  'USP51',
#  'IGF2BP2',
#  'PPIAL4G',
#  'TNNC1',
#  'B4GALT2',
#  'EFCC1',
#  'FAIM',
#  'FAM110B',
#  'EFNB2',
#  'FTL',
#  'LRIF1',
#  'MAP3K1',
#  'SLC39A2',
#  'STAMBPL1',
#  'ARIH1',
#  'CCDC85C',
#  'SIGLEC9',
#  'NOP9',
#  'CYB561D2',
#  'POLD1',
#  'CDC23',
#  'CT47A6',
#  'SVIL',
#  'SRRM4',
#  'ABCC1',
#  'C16orf82',
#  'LIN52',
#  'MYH4',
#  'CLIC3',
#  'FOXRED2',
#  'KRTAP10-4',
#  'FAM184B',
#  'BLOC1S5',
#  'HECTD1',
#  'GGPS1',
#  'ASNSD1',
#  'STAT4',
#  'NDRG1',
#  'ATP2B1',
#  'EFS',
#  'IKZF3',
#  'DYNC1H1',
#  'SEPT12',
#  'NPTN',
#  'ARHGAP4',
#  'RGMB',
#  'POU4F3',
#  'KCNK10',
#  'NDUFC1',
#  'TGFBR1',
#  'IBA57',
#  'TAS2R42',
#  'IRF8',
#  'USH1G',
#  'IFITM10',
#  'IMPDH2',
#  'MAP3K9',
#  'CIAO1',
#  'AQP2',
#  'CAPN1',
#  'OR6N1',
#  'CALCOCO2',
#  'CACNG5',
#  'BTN3A2',
#  'PASK',
#  'ZNF507',
#  'DDX55',
#  'GPN1',
#  'EFNA1',
#  'NCMAP',
#  'ZNF582',
#  'TENM1',
#  'FAM131C',
#  'ZNF554',
#  'LIMD2',
#  'GUCY2F',
#  'BPY2B',
#  'RPL12',
#  'IRAK2',
#  'DYRK4',
#  'OR6F1',
#  'C4orf36',
#  'FZD6',
#  'SUMF1',
#  'ACSM2B',
#  'CCDC43',
#  'SOST',
#  'ZKSCAN8',
#  'FAM129B',
#  'OR8I2',
#  'HIRA',
#  'CLASRP',
#  'FCRL3',
#  'MRPS22',
#  'MSGN1',
#  'TEC',
#  'AGGF1',
#  'C9orf43',
#  'NAA25',
#  'RILPL2',
#  'EMILIN1',
#  'TECPR2',
#  'C16orf46',
#  'CPD',
#  'EXOC7',
#  'FOXS1',
#  'IBSP',
#  'NOL8',
#  'RNF144A',
#  'LILRA6',
#  'GCAT',
#  'GAB1',
#  'COLCA1',
#  'MRPS2',
#  'ALKBH2',
#  'CORO1B',
#  'BRCC3',
#  'SLC22A18AS',
#  'EMID1',
#  'MAD2L1',
#  'MAPK8IP1',
#  'BHLHA9',
#  'DNA2',
#  'RHAG',
#  'TWF1',
#  'AK3',
#  'DNAH10',
#  'RTN4',
#  'PTPN12',
#  'APOL5',
#  'FAM131B',
#  'PANX1',
#  'AP1S1',
#  'PUS1',
#  'PRR19',
#  'ASPDH',
#  'SLC19A1',
#  'SYNGAP1',
#  'CLDN11',
#  'SLC32A1',
#  'USP45',
#  'IFNA17',
#  'POFUT1',
#  'PCDH20',
#  'MOB3A',
#  'VPREB3',
#  'MFAP2',
#  'SHC1',
#  'FAM98A',
#  'B3GALT1',
#  'SLC17A8',
#  'SRSF5',
#  'TBL3',
#  'SURF4',
#  'TKTL1',
#  'GSR',
#  'RAX2',
#  'DERL3',
#  'BECN1',
#  'MAPK10',
#  'LRCH4',
#  'FKBP4',
#  'EPG5',
#  'TMPRSS2',
#  'ZNF300',
#  'NIF3L1',
#  'GPRASP2',
#  'OR9Q1',
#  'TMEM183A',
#  'DUSP26',
#  'ACTL7A',
#  'NR6A1',
#  'DEPTOR',
#  'MED19',
#  'SEC24A',
#  'BLOC1S3',
#  'TAP1',
#  'CNKSR2',
#  'RNASEH2B',
#  'RUSC2',
#  'OR5H15',
#  'CALY',
#  'ASB16',
#  'CYP3A5',
#  'SERPINA13P',
#  'S100G',
#  'SCGN',
#  'F11',
#  'RPTOR',
#  'NLK',
#  'QRICH1',
#  'AQP8',
#  'FNDC3B',
#  'USP17L11',
#  'TCERG1',
#  'PAICS',
#  'MUL1',
#  'UGT1A4',
#  'CYP4F11',
#  'RAET1L',
#  'LETM2',
#  'RNF183',
#  'MAGEA4',
#  'CBLN1',
#  'OR4D2',
#  'SH3TC2',
#  'GBX1',
#  'ALG10',
#  'SMAD4',
#  'ADRB1',
#  'HIF1AN',
#  'THEMIS2',
#  'PRSS57',
#  'TMEM201',
#  'POLDIP2',
#  'CISH',
#  'AADACL4',
#  'MRFAP1',
#  'FAM47E-STBD1',
#  'PIK3CA',
#  'ASB5',
#  'SFXN4',
#  'GPR34',
#  'NDFIP1',
#  'EGR4',
#  'CCT8',
#  'FPR3',
#  'OR5B21',
#  'HIBADH',
#  'LACE1',
#  'REEP2',
#  'DCDC2B',
#  'ZCCHC2',
#  'WDR54',
#  'BNIP2',
#  'SLC30A3',
#  'PRRC2B',
#  'ATF7IP2',
#  'PELI1',
#  'SIGIRR',
#  'MACROD1',
#  'G6PC2',
#  'PTN',
#  'BNC2',
#  'DDB1',
#  'NPIPA5',
#  'C1QTNF1',
#  'DGKQ',
#  'PCDHA7',
#  'THG1L',
#  'ANAPC15',
#  'MEF2A',
#  'ATG9B',
#  'GJB5',
#  'PSMC6',
#  'PROCA1',
#  'SETDB2',
#  'GPC2',
#  'IGHMBP2',
#  'SLC25A24',
#  'VPS29',
#  'VMP1',
#  'NONO',
#  'PCDHGB2',
#  'PHOSPHO1',
#  'B3GALT4',
#  'ZNF709',
#  'REEP3',
#  'TNFSF11',
#  'LRRN3',
#  'TAS2R10',
#  'CHST9',
#  'ACVR1C',
#  'SLC25A29',
#  'TAF9B',
#  'DCLK2',
#  'THYN1',
#  'FAM98B',
#  'PNMT',
#  'FDXACB1',
#  'CNN3',
#  'TP53TG3B',
#  'PABPC4L',
#  'PKD2L1',
#  'DEFA4',
#  'MRPL20',
#  'C7orf65',
#  'PRPF3',
#  'ZNF117',
#  'DDX5',
#  'CMBL',
#  'MAZ',
#  'TMSB15B',
#  'FBXO48',
#  'TSPAN6',
#  'FKBP7',
#  'IFT46',
#  'PDCD7',
#  'SEZ6',
#  'GPR89A',
#  'DRD3',
#  'UBL4A',
#  'DEFA1',
#  'PIP4K2A',
#  'CYB561D1',
#  'GABRB2',
#  'OR8D4',
#  'GAGE12F',
#  'CHAC1',
#  'LSP1',
#  'SNX15',
#  'C7orf72',
#  'NOX5',
#  'ARHGEF39',
#  'GPR137',
#  'FIGNL1',
#  'LYZL2',
#  'DESI2',
#  'ALDH3B1',
#  'CLTC',
#  'SMIM1',
#  'INTU',
#  'LRGUK',
#  'CMPK1',
#  'ELK4',
#  'PLA2G4F',
#  'STAT2',
#  'ZC3H12A',
#  'HIP1',
#  'SLC37A3',
#  'KANSL1',
#  'ATP4B',
#  'RINL',
#  'PRKD1',
#  'SF3B5',
#  'CHN1',
#  'TSEN2',
#  'C9orf50',
#  'NDUFA4L2',
#  'P2RY8',
#  'ELP2',
#  'SYNE3',
#  'ATP11C',
#  ...}

# %%
set(gene_list_df1_1["Synonyms_separated"].tolist())
# Out:
# {'-',
#  '61E3.4',
#  'AAP1',
#  'AB13',
#  'AB14',
#  'AB23',
#  'ACPL2',
#  'AD-004',
#  'AD026',
#  'AD2',
#  'AIPDS',
#  'APAP-1',
#  'ASXH2',
#  'AZ1',
#  'AZ2',
#  'AZI1',
#  'B7-H5',
#  'B7H5',
#  'BJHCC20A',
#  'BRCC1',
#  'BRP16',
#  'BRP16L',
#  'C10orf112',
#  'C10orf118',
#  'C10orf137',
#  'C10orf54',
#  'C11orf35',
#  'C11orf82',
#  'C12orf23',
#  'C12orf39',
#  'C12orf44',
#  'C12orf52',
#  'C12orf68',
#  'C14orf164',
#  'C15orf38',
#  'C15orf60',
#  'C16orf29',
#  'C17orf72',
#  'C17orf76',
#  'C19orf55',
#  'C19orf59',
#  'C19orf69',
#  'C19orf77',
#  'C1orf163',
#  'C1orf170',
#  'C1orf172',
#  'C1orf173',
#  'C1orf227',
#  'C1orf51',
#  'C1orf63',
#  'C1orf65',
#  'C20orf105',
#  'C20orf112',
#  'C20orf113',
#  'C20orf131',
#  'C20orf132',
#  'C20orf201',
#  'C22orf36',
#  'C22orf43',
#  'C2orf85',
#  'C3orf44',
#  'C4orf21',
#  'C6orf84',
#  'C7orf10',
#  'C7orf41',
#  'C8orf30A',
#  'C8orf30B',
#  'C8orf47',
#  'C9orf169',
#  'C9orf96',
#  'CCBP1',
#  'CCCP-1',
#  'CCCP1',
#  'CCDC165',
#  'CCDC41',
#  'CCSP1',
#  'CD234',
#  'CDG1Z',
#  'CDG2W',
#  'CEBPZ-AS1',
#  'CEMIP1',
#  'CENP50',
#  'CENPU50',
#  'CFAP9',
#  'CGI-110',
#  'CGI-12',
#  'CGI-137',
#  'CHRONO',
#  'CINAP',
#  'CIP',
#  'COL29A1',
#  'CT147',
#  'CXXC11',
#  'CXorf48',
#  'DARC',
#  'DARC/ACKR1',
#  'DD1alpha',
#  'DEDAF',
#  'DEE50',
#  'DERP13',
#  'DHHC-11B',
#  'DIET1',
#  'Dfy',
#  'Dies1',
#  'ECTD12',
#  'EIEE50',
#  'ERICH6A',
#  'Ells1',
#  'FAM105B',
#  'FAM194A',
#  'FAM203A',
#  'FAM203B',
#  'FAM211A',
#  'FAM211B',
#  'FAP9',
#  'FGQTL5',
#  'FOAP-7',
#  'FONG',
#  'FY',
#  'G1',
#  'G6PT',
#  'G6PT1',
#  'G6PT2',
#  'G6PT3',
#  'GA3',
#  'GARLH4',
#  'GATD4',
#  'GCP-1',
#  'GCP1',
#  'GENEX3414',
#  'GENX-3414',
#  'GI24',
#  'GKAF',
#  'GKRP',
#  'GLTPD1',
#  'GM129',
#  'GPD',
#  'GSD1b',
#  'GSD1c',
#  'GSD1d',
#  'GUM',
#  'GpFy',
#  'HEL124',
#  'HEL2',
#  'HEMO',
#  'HSPC035',
#  'HSPC175',
#  'HSPC323',
#  'HYBID',
#  'Ht006',
#  'IFLTD1',
#  'IL-27',
#  'IL-27A',
#  'IL17E',
#  'IL27A',
#  'IL27p28',
#  'IL30',
#  'IL8',
#  'IMD107',
#  'JADE-2',
#  'JADE-3',
#  'JHDM1D',
#  'KB-208E9.1',
#  'KIAA0802',
#  'KIAA0947',
#  'KIAA1009',
#  'KIAA1199',
#  'KIAA1239',
#  'KIAA1737',
#  'KLIP1',
#  'LECT',
#  'LMNARS1',
#  'LRDD',
#  'LSMD1',
#  'LUCT',
#  'LYNAP',
#  'MAK31',
#  'MARDI',
#  'MCCCHCM',
#  'MDNCF',
#  'MKI67IP',
#  'MLF1IP',
#  'MLP',
#  'MONAP',
#  'MRD71',
#  'MRP63',
#  'MRT75',
#  'MTERF',
#  'MTERFD1',
#  'MTERFD2',
#  'MTERFD3',
#  'MUC-19',
#  'MUC-2',
#  'MYO15BP',
#  'NAF',
#  'NAP-1',
#  'NAP1',
#  'NAPRT1',
#  'NARG2',
#  'NBG',
#  'NBPF',
#  'NEUR1',
#  'NEURL',
#  'NIM1',
#  'NPD014',
#  'NPHP18',
#  'NPIP',
#  'NY-REN-58',
#  'Nopp34',
#  'OOMD10',
#  'ORF19',
#  'OZEMA10',
#  'P14',
#  'PAS1C1',
#  'PBIP1',
#  'PD-1H',
#  'PFAAP2',
#  'PFBMFT5',
#  'PHF15',
#  'PHF16',
#  'PHF17',
#  'PIDD',
#  'PP2135',
#  'PP3856',
#  'PRG',
#  'PRMT10',
#  'PRO0685',
#  'QN1',
#  'RAB7L',
#  'RAB7L1',
#  'RABL5',
#  'RESA1',
#  'RFXDC2',
#  'RITA',
#  'RNF67',
#  'SAP14',
#  'SAP14a',
#  'SAST',
#  'SCAN3',
#  'SCYB8',
#  'SELRC1',
#  'SF3B14',
#  'SF3B14a',
#  'SHAPNS',
#  'SISP1',
#  'SMUC',
#  'SOGA2',
#  'SPGFX7',
#  'SPX1',
#  'SPX4',
#  'SgK071',
#  'Sk521',
#  'TILP',
#  'TMEM2L',
#  'TMEM66',
#  'TRG-19',
#  'TRG19',
#  'VISTA',
#  'VWA4',
#  'WBCQ1',
#  'XTP3',
#  'XYLP',
#  'YEAF1',
#  'Z3CXXC5',
#  'ZA1',
#  'ZNF259',
#  'bA255A11.3',
#  'bA255A11.5',
#  'bA265G8.2',
#  'bA416N2.1',
#  'bMRP63',
#  'dJ1153D9.2',
#  'envMER34',
#  'gcnt',
#  'golgin104',
#  'hCINAP',
#  'mL63',
#  'mTERFL',
#  'neu',
#  'neu-1',
#  'noxin',
#  'p28'}

# %%
mapping_list = list(set(cho_et_al_tpm.columns.tolist())&set(gene_list_df1_1["Synonyms_separated"].tolist()))

print("length of mapping list", len(mapping_list))
# Out:
# length of mapping list 0

# %%
genes_mapping = gene_list_df1_1[gene_list_df1_1["Synonyms_separated"].isin(mapping_list)]
genes_mapping_dict = {}
for index, row in genes_mapping.iterrows():
    genes_mapping_dict[row["Synonyms_separated"]] = row["Symbol"]
# add the other one which has synonyms in the list  
genes_mapping_dict

# %%
for index, row in gene_list_df2_1.iterrows():
    genes_mapping_dict[row["Symbol"]] = row["Synonyms_separated"]
genes_mapping_dict
# Out:
# {'LRMP': 'IRAG2',
#  'WARS': 'WARS1',
#  'YARS': 'YARS1',
#  'GCKR': 'MAP4K5',
#  'NPIPB5': 'NPIPB3',
#  'MAST1': 'CLASP1',
#  'FAM19A5': 'TAFA5',
#  'NAA38': 'LSM8',
#  'FAM105A': 'OTULINL',
#  'IL25': 'MYDGF',
#  'IL27': 'MYDGF',
#  'AZI2': 'AZIN2',
#  'FAM150B': 'ALKAL2',
#  'TMEM173': 'STING1',
#  'FAM159A': 'SHISAL2A',
#  'LHFPL4': 'LHFPL3',
#  'FAM150A': 'ALKAL1',
#  'CAD': 'ACOD1',
#  'FAM200C': 'ZBED8',
#  'SCAND3': 'ZBED9',
#  'GGT2P': 'GGT2',
#  'LOC102724197': 'GGT2'}

# %%
cho_et_al_tpm = cho_et_al_tpm.rename(columns=genes_mapping_dict)
# add dummy value to the group for genes
new_mapping_list = list(set(compass_example_data_genelist) - set(cho_et_al_tpm.columns.tolist()))

new_mapping_list
# Out:
# ['SAMD1',
#  'CENPU',
#  'C19orf84',
#  'SF3B6',
#  'AK6',
#  'RFX7',
#  'RYBP',
#  'FTCDNL1',
#  'GGT2',
#  'ANKRD36C',
#  'PLSCR3',
#  'C3orf49',
#  'NEURL1',
#  'LKAAEAR1',
#  'JADE2',
#  'CEBPZOS',
#  'C8orf88',
#  'AZI2',
#  'RAB29',
#  'NAA38',
#  'MS4A4E',
#  'PIDD1',
#  'ARPIN',
#  'SMIM24',
#  'CCDC184',
#  'TMIGD3',
#  'MTERF3',
#  'GCNT7',
#  'RSRP1',
#  'ERVMER34-1',
#  'ZNF670-ZNF695',
#  'GCKR',
#  'MTURN',
#  'MUC2',
#  'CEP131',
#  'NOL4L',
#  'NPIPB5',
#  'LRRC75B',
#  'LHFPL4',
#  'CIPC',
#  'ERICH3',
#  'MAST1',
#  'PRMT9',
#  'RPEL1',
#  'LRRC75A',
#  'PRR29',
#  'OTULIN',
#  'HGH1',
#  'SARAF',
#  'ICE2',
#  'NIFK',
#  'ERICH5',
#  'TMEM262',
#  'MYO15B',
#  'ZNF738',
#  'NPIPB11',
#  'RITA1',
#  'MTERF1',
#  'MALRD1',
#  'COL6A5',
#  'ANKRD18B',
#  'CXCL8',
#  'PROSER3',
#  'CAD',
#  'ACKR1',
#  'SLC37A4',
#  'ZPR1',
#  'LMNTD1',
#  'NPIPB4',
#  'CT55',
#  'ZBED9',
#  'TMEM263',
#  'HMCN2',
#  'KDF1',
#  'CEP162',
#  'SPATA45',
#  'NAPRT',
#  'MTCL1',
#  'Index',
#  'DRICH1',
#  'cancer_code',
#  'CCDC185',
#  'ZNF598',
#  'NT5DC4',
#  'ATG101',
#  'C1orf167',
#  'MCEMP1',
#  'ZNF852',
#  'CEMIP',
#  'ZCCHC8',
#  'RTP5',
#  'ZGRF1',
#  'MTERF2',
#  'DDIAS',
#  'CIART',
#  'FOXO6',
#  'PERM1',
#  'ERICH6',
#  'NWD2',
#  'MTERF4',
#  'PXYLP1',
#  'NBPF1',
#  'ICE1',
#  'LMNTD2',
#  'CCDC186',
#  'ZDHHC11B',
#  'JADE1',
#  'STBD1',
#  'MUC19',
#  'REC114',
#  'IL25',
#  'CCDC154',
#  'KDM7A',
#  'SUGCT',
#  'ERICH4',
#  'IL27',
#  'MROH8',
#  'PRB3',
#  'IFT22',
#  'CEP83',
#  'COA7',
#  'JADE3',
#  'NIM1K',
#  'CYSRT1',
#  'FBLL1',
#  'MRPL57',
#  'SPX',
#  'ZBED8',
#  'CPTP',
#  'EDRF1',
#  'RNF212B',
#  'ASXL2',
#  'STKLD1',
#  'CLASP2',
#  'VSIR']

# %%
cho_et_al[new_mapping_list] = 0.00
cho_et_al

# %%
cho_et_al.shape

# %%
cho_et_al_cleaned = cho_et_al.loc[:, cho_et_al.columns.isin(compass_example_data_genelist)]
cho_et_al_cleaned

# %%
cho_et_al_cleaned["cancer_code"] = 16 # TCGA isn't having a broad type code but uses LUAD 
cho_et_al_cleaned = cho_et_al_cleaned[compass_example_data_genelist]
cho_et_al_cleaned = cho_et_al_cleaned.drop(columns="Index")

# %%
cho_et_al_cleaned = cho_et_al_cleaned.drop(columns="cancer_code")
cho_et_al_cleaned

# %%
# map the genes with gene id
# file from COMPASS-web
genes_mapping_compass = pd.read_csv("/Users/z5155527/Desktop/Benchmark-2025-Sep/phase_1_datasets/bulk_RNA-seq/compass/compass_gene_map.csv")
genes_mapping_compass

# %%
mapping_id_dict = {}
mapping_id_dict_back = {}
for index, row in genes_mapping_compass.iterrows():
    mapping_id_dict[row["gene_name"]] = row["ensid_v36"]
    mapping_id_dict_back[row["ensid_v36"]] = row["gene_name"]
mapping_id_dict_back

# %%
# rename
cho_et_al_cleaned = cho_et_al_cleaned.rename(columns=mapping_id_dict)
cho_et_al_cleaned

# %%
# then transform back 
cho_et_al_tpm = pd.read_csv('/Users/z5155527/Desktop/Benchmark-2025-Sep/phase_1_datasets/bulk_RNA-seq/compass/unstranded_tpm.csv')
cho_et_al_tpm = cho_et_al_tpm.rename(columns={"Unnamed: 0": "Index"})
cho_et_al_tpm = cho_et_al_tpm.rename(columns=mapping_id_dict_back)
cho_et_al_tpm = cho_et_al_tpm[compass_example_data_genelist]
cho_et_al_tpm

# %%
code_16_patients = cho_et_al_clinical.loc[cho_et_al_clinical["Histology"]=="Adenocarcinoma", "ID"]
cho_et_al_tpm.loc[cho_et_al_tpm["Index"].isin(code_16_patients), "cancer_code"] = 16
code_17_patients = cho_et_al_clinical.loc[cho_et_al_clinical["Histology"]=="Squamous_cell_carcinoma", "ID"]
cho_et_al_tpm.loc[cho_et_al_tpm["Index"].isin(code_17_patients), "cancer_code"] = 17
cho_et_al_tpm

# %%
tpm = TPM(gtf_path).set_output(transform="pandas")
tmm = TMM(m_trim = 0.3, a_trim = 0.05).set_output(transform="pandas")


## counts, TPM, TMM
df_counts = cho_et_al_cleaned
df_tpm = tpm.fit_transform(df_counts)
df_tmm = tmm.fit_transform(df_counts)

df_counts.to_csv('/Users/z5155527/Desktop/Benchmark-2025-Sep/phase_1_datasets/bulk_RNA-seq/compass/untranded_counts.csv')
df_tpm.to_csv('/Users/z5155527/Desktop/Benchmark-2025-Sep/phase_1_datasets/bulk_RNA-seq/compass/unstranded_tpm.csv')

# %%
# save the final output
cho_et_al_tpm.to_csv("/Users/z5155527/Desktop/Benchmark-2025-Sep/phase_1_datasets/bulk_RNA-seq/compass/cho_et_al_cleaned_TPM.tsv", sep='\t', index=False)

# %%
cho_et_al_clinical["response_binary"] = 0
cho_et_al_clinical.loc[cho_et_al_clinical["Responsiveness"]=="Responder", "response_binary"] = 1
cho_et_al_clinical

# %%
cho_et_al_clinical.to_csv("/Users/z5155527/Desktop/Benchmark-2025-Sep/phase_1_datasets/bulk_RNA-seq/compass/cho_et_al_clinical.tsv", sep='\t', index=False)
